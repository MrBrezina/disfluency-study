# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import researchpy as rp
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import statsmodels.stats.multicomp
from itertools import combinations

datafilename = "data_processed-without-outliers.csv"
d = pd.read_csv(datafilename)
print("Loading", len(d), "lines of data (outliers removed).")

resultsfilename = "data_stats-without-outliers.csv"
st = pd.read_csv(resultsfilename)
print("Loading", len(st), "lines of stats.")

# ------------------------------------------------------
# functions to add eta squared and omega squared
# to the ANOVA summary table

def eta_squared(aov):
    aov['eta_sq'] = 'NaN'
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    return aov

def omega_squared(aov):
    mse = aov['sum_sq'][-1]/aov['df'][-1]
    aov['omega_sq'] = 'NaN'
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*mse))/(sum(aov['sum_sq'])+mse)
    return aov
# Out:
# Loading 14520 lines of data (outliers removed).
# Loading 808 lines of stats.

# %%
factors = ["StudyID", "Training", "Font", "Firstfont"]
metrics = ["RT", "AUC", "AUC_word"]

def anova(factor, metrics, no):
    for f in combinations(factors, no):
        if f[0] != f[1]:
            f_ = ["C(%s)" % x for x in f]
            for metric in metrics:
                formula = metric + " ~ " + (" * ".join(f_))
                model = ols(formula, st).fit()
                aov_table = anova_lm(model, typ=2)
                eta_squared(aov_table)
                omega_squared(aov_table)
                print()
                print("# %s (metric: %s)" % (f, metric))
                print()
                display(aov_table)
                # overall model significance
                print(f"Overall model F(%d, %d) = %.3f, p = %.4f" % (model.df_model, model.df_resid, model.fvalue, model.f_pvalue))
                print()

anova(factors, metrics, 2)
print(30 * "_")
anova(factors, metrics, 3)
# Out:
# # ('StudyID', 'Training') (metric: RT)
#                               sum_sq     df         F    PR(>F)    eta_sq  \
# C(StudyID)              1.983269e+04    1.0  0.021936  0.882295  0.000026
# C(Training)             2.375288e+07    4.0  6.567933  0.000033  0.031498
# C(StudyID):C(Training)  8.845468e+06    4.0  2.445869  0.045115  0.011730
# Residual                7.214904e+08  798.0       NaN       NaN       NaN
#
#                         omega_sq
# C(StudyID)             -0.001171
# C(Training)             0.026670
# C(StudyID):C(Training)  0.006926
# Residual                     NaN
# Overall model F(9, 798) = 4.030, p = 0.0000
#
# # ('StudyID', 'Training') (metric: AUC)
#                           sum_sq     df          F    PR(>F)    eta_sq  \
# C(StudyID)              0.182620    1.0  16.082524  0.000066  0.019118
# C(Training)             0.190207    4.0   4.187671  0.002313  0.019912
# C(StudyID):C(Training)  0.118228    4.0   2.602952  0.034819  0.012377
# Residual                9.061438  798.0        NaN       NaN       NaN
#
#                         omega_sq
# C(StudyID)              0.017908
# C(Training)             0.015139
# C(StudyID):C(Training)  0.007613
# Residual                     NaN
# Overall model F(9, 798) = 5.366, p = 0.0000
#
# # ('StudyID', 'Training') (metric: AUC_word)
#                           sum_sq     df         F    PR(>F)    eta_sq  \
# C(StudyID)              0.048573    1.0  2.293613  0.130709  0.005709
# C(Training)             0.108734    4.0  1.283586  0.275790  0.012779
# C(StudyID):C(Training)  0.007414    4.0  0.087519  0.986303  0.000871
# Residual                8.344011  394.0       NaN       NaN       NaN
#
#                         omega_sq
# C(StudyID)              0.003212
# C(Training)             0.002816
# C(StudyID):C(Training) -0.009062
# Residual                     NaN
# Overall model F(9, 394) = 0.956, p = 0.4765
#
# # ('StudyID', 'Font') (metric: RT)
#                           sum_sq     df          F    PR(>F)    eta_sq  \
# C(StudyID)          1.954813e+05    1.0   0.212846  0.644671  0.000259
# C(Font)             1.532682e+07    1.0  16.688305  0.000048  0.020320
# C(StudyID):C(Font)  3.549959e+05    1.0   0.386530  0.534305  0.000471
# Residual            7.384069e+08  804.0        NaN       NaN       NaN
#
#                     omega_sq
# C(StudyID)         -0.000957
# C(Font)             0.019079
# C(StudyID):C(Font) -0.000746
# Residual                 NaN
# Overall model F(3, 804) = 5.763, p = 0.0007
#
# # ('StudyID', 'Font') (metric: AUC)
#                       sum_sq     df          F    PR(>F)    eta_sq  omega_sq
# C(StudyID)          0.239968    1.0  20.602960  0.000007  0.024971  0.023730
# C(Font)             0.000395    1.0   0.033892  0.853983  0.000041 -0.001170
# C(StudyID):C(Font)  0.005094    1.0   0.437386  0.508577  0.000530 -0.000681
# Residual            9.364384  804.0        NaN       NaN       NaN       NaN
# Overall model F(3, 804) = 7.025, p = 0.0001
#
# # ('StudyID', 'Font') (metric: AUC_word)
#                       sum_sq     df         F    PR(>F)    eta_sq  omega_sq
# C(StudyID)          0.066015    1.0  3.122063  0.078001  0.007743  0.005250
# C(Font)             0.000087    1.0  0.004115  0.948881  0.000010 -0.002464
# C(StudyID):C(Font)  0.002145    1.0  0.101422  0.750296  0.000252 -0.002223
# Residual            8.457927  400.0       NaN       NaN       NaN       NaN
# Overall model F(3, 400) = 1.076, p = 0.3591
#
# # ('StudyID', 'Firstfont') (metric: RT)
#                                sum_sq     df         F    PR(>F)    eta_sq  \
# C(StudyID)               1.317565e+05    1.0  0.143041  0.705376  0.000175
# C(Firstfont)             7.054584e+06    1.0  7.658776  0.005780  0.009353
# C(StudyID):C(Firstfont)  6.460738e+06    1.0  7.014070  0.008246  0.008566
# Residual                 7.405734e+08  804.0       NaN       NaN       NaN
#
#                          omega_sq
# C(StudyID)              -0.001045
# C(Firstfont)             0.008122
# C(StudyID):C(Firstfont)  0.007336
# Residual                      NaN
# Overall model F(3, 804) = 4.962, p = 0.0020
#
# # ('StudyID', 'Firstfont') (metric: AUC)
#                            sum_sq     df          F    PR(>F)    eta_sq  \
# C(StudyID)               0.243532    1.0  20.948756  0.000005  0.025333
# C(Firstfont)             0.016694    1.0   1.436004  0.231140  0.001737
# C(StudyID):C(Firstfont)  0.006589    1.0   0.566779  0.451762  0.000685
# Residual                 9.346591  804.0        NaN       NaN       NaN
#
#                          omega_sq
# C(StudyID)               0.024094
# C(Firstfont)             0.000527
# C(StudyID):C(Firstfont) -0.000523
# Residual                      NaN
# Overall model F(3, 804) = 7.548, p = 0.0001
#
# # ('StudyID', 'Firstfont') (metric: AUC_word)
#                            sum_sq     df         F    PR(>F)    eta_sq  \
# C(StudyID)               0.064985    1.0  3.083541  0.079853  0.007623
# C(Firstfont)             0.004084    1.0  0.193802  0.660009  0.000479
# C(StudyID):C(Firstfont)  0.026164    1.0  1.241500  0.265851  0.003069
# Residual                 8.429910  400.0       NaN       NaN       NaN
#
#                          omega_sq
# C(StudyID)               0.005138
# C(Firstfont)            -0.001988
# C(StudyID):C(Firstfont)  0.000596
# Residual                      NaN
# Overall model F(3, 400) = 1.523, p = 0.2081
#
# # ('Training', 'Font') (metric: RT)
#                            sum_sq     df          F    PR(>F)    eta_sq  \
# C(Training)          2.392853e+07    4.0   6.684818  0.000027  0.031723
# C(Font)              1.532682e+07    1.0  17.127163  0.000039  0.020320
# C(Training):C(Font)  9.118241e+05    4.0   0.254733  0.906816  0.001209
# Residual             7.141170e+08  798.0        NaN       NaN       NaN
#
#                      omega_sq
# C(Training)          0.026946
# C(Font)              0.019111
# C(Training):C(Font) -0.003533
# Residual                  NaN
# Overall model F(9, 798) = 4.987, p = 0.0000
#
# # ('Training', 'Font') (metric: AUC)
#                        sum_sq     df         F    PR(>F)    eta_sq  omega_sq
# C(Training)          0.247555    4.0  5.285119  0.000333  0.025761  0.020861
# C(Font)              0.000395    1.0  0.033710  0.854371  0.000041 -0.001176
# C(Training):C(Font)  0.017320    4.0  0.369759  0.830263  0.001802 -0.003068
# Residual             9.344572  798.0       NaN       NaN       NaN       NaN
# Overall model F(9, 798) = 2.517, p = 0.0076
#
# # ('Training', 'Font') (metric: AUC_word)
#                        sum_sq     df         F    PR(>F)    eta_sq  omega_sq
# C(Training)          0.126176    4.0  1.493508  0.203354  0.014799  0.004878
# C(Font)              0.000087    1.0  0.004120  0.948853  0.000010 -0.002461
# C(Training):C(Font)  0.078368    4.0  0.927626  0.447763  0.009192 -0.000715
# Residual             8.321543  394.0       NaN       NaN       NaN       NaN
# Overall model F(9, 394) = 1.077, p = 0.3790
#
# # ('Training', 'Firstfont') (metric: RT)
#                                 sum_sq     df         F    PR(>F)    eta_sq  \
# C(Training)               2.277821e+07    4.0  6.347953  0.000050  0.030245
# C(Firstfont)              5.967989e+06    1.0  6.652764  0.010078  0.007924
# C(Training):C(Firstfont)  8.526485e+06    4.0  2.376206  0.050566  0.011321
# Residual                  7.158612e+08  798.0       NaN       NaN       NaN
#
#                           omega_sq
# C(Training)               0.025450
# C(Firstfont)              0.006725
# C(Training):C(Firstfont)  0.006549
# Residual                       NaN
# Overall model F(9, 798) = 4.759, p = 0.0000
#
# # ('Training', 'Firstfont') (metric: AUC)
#                             sum_sq     df         F    PR(>F)    eta_sq  \
# C(Training)               0.249878    4.0  5.531245  0.000215  0.025996
# C(Firstfont)              0.015453    1.0  1.368256  0.242461  0.001608
# C(Training):C(Firstfont)  0.334276    4.0  7.399456  0.000007  0.034776
# Residual                  9.012558  798.0       NaN       NaN       NaN
#
#                           omega_sq
# C(Training)               0.021271
# C(Firstfont)              0.000432
# C(Training):C(Firstfont)  0.030041
# Residual                       NaN
# Overall model F(9, 798) = 5.876, p = 0.0000
#
# # ('Training', 'Firstfont') (metric: AUC_word)
#                             sum_sq     df         F    PR(>F)    eta_sq  \
# C(Training)               0.128196    4.0  1.541740  0.189313  0.015032
# C(Firstfont)              0.007135    1.0  0.343242  0.558300  0.000837
# C(Training):C(Firstfont)  0.202577    4.0  2.436277  0.046737  0.023754
# Residual                  8.190286  394.0       NaN       NaN       NaN
#
#                           omega_sq
# C(Training)               0.005269
# C(Firstfont)             -0.001597
# C(Training):C(Firstfont)  0.013970
# Residual                       NaN
# Overall model F(9, 394) = 1.795, p = 0.0674
#
# # ('Font', 'Firstfont') (metric: RT)
#                             sum_sq     df          F    PR(>F)    eta_sq  \
# C(Font)               1.532682e+07    1.0  16.941449  0.000043  0.020320
# C(Firstfont)          7.118309e+06    1.0   7.868201  0.005153  0.009437
# C(Font):C(Firstfont)  4.465667e+06    1.0   4.936112  0.026579  0.005920
# Residual              7.273734e+08  804.0        NaN       NaN       NaN
#
#                       omega_sq
# C(Font)               0.019097
# C(Firstfont)          0.008228
# C(Font):C(Firstfont)  0.004715
# Residual                   NaN
# Overall model F(3, 804) = 9.915, p = 0.0000
#
# # ('Font', 'Firstfont') (metric: AUC)
#                         sum_sq     df         F    PR(>F)    eta_sq  omega_sq
# C(Font)               0.000395    1.0  0.033133  0.855610  0.000041 -0.001197
# C(Firstfont)          0.013130    1.0  1.102033  0.294136  0.001366  0.000126
# C(Font):C(Firstfont)  0.017353    1.0  1.456545  0.227836  0.001806  0.000565
# Residual              9.578963  804.0       NaN       NaN       NaN       NaN
# Overall model F(3, 804) = 0.864, p = 0.4594
#
# # ('Font', 'Firstfont') (metric: AUC_word)
#                         sum_sq     df         F    PR(>F)    eta_sq  omega_sq
# C(Font)               0.000087    1.0  0.004111  0.948908  0.000010 -0.002466
# C(Firstfont)          0.005115    1.0  0.241650  0.623287  0.000600 -0.001878
# C(Font):C(Firstfont)  0.054388    1.0  2.569526  0.109730  0.006379  0.003887
# Residual              8.466584  400.0       NaN       NaN       NaN       NaN
# Overall model F(3, 400) = 0.938, p = 0.4220
#
# ______________________________
# # ('StudyID', 'Training', 'Font') (metric: RT)
#                                       sum_sq     df          F    PR(>F)  \
# C(StudyID)                      1.983269e+04    1.0   0.022185  0.881633
# C(Training)                     2.375288e+07    4.0   6.642679  0.000029
# C(Font)                         1.532682e+07    1.0  17.145052  0.000038
# C(StudyID):C(Training)          8.845468e+06    4.0   2.473704  0.043109
# C(StudyID):C(Font)              5.195938e+05    1.0   0.581234  0.446057
# C(Training):C(Font)             1.076422e+06    4.0   0.301030  0.877320
# C(StudyID):C(Training):C(Font)  2.997330e+05    4.0   0.083823  0.987399
# Residual                        7.044324e+08  788.0        NaN       NaN
#
#                                   eta_sq  omega_sq
# C(StudyID)                      0.000026 -0.001158
# C(Training)                     0.031491  0.026719
# C(Font)                         0.020320  0.019112
# C(StudyID):C(Training)          0.011727  0.006978
# C(StudyID):C(Font)              0.000689 -0.000496
# C(Training):C(Font)             0.001427 -0.003310
# C(StudyID):C(Training):C(Font)  0.000397 -0.004338
# Residual                             NaN       NaN
# Overall model F(19, 788) = 2.935, p = 0.0000
#
# # ('StudyID', 'Training', 'Font') (metric: AUC)
#                                   sum_sq     df          F    PR(>F)  \
# C(StudyID)                      0.182620    1.0  15.940010  0.000071
# C(Training)                     0.190207    4.0   4.150562  0.002470
# C(Font)                         0.000395    1.0   0.034456  0.852789
# C(StudyID):C(Training)          0.118228    4.0   2.579886  0.036184
# C(StudyID):C(Font)              0.002940    1.0   0.256618  0.612595
# C(Training):C(Font)             0.015165    4.0   0.330923  0.857246
# C(StudyID):C(Training):C(Font)  0.012898    4.0   0.281447  0.890060
# Residual                        9.027886  788.0        NaN       NaN
#
#                                   eta_sq  omega_sq
# C(StudyID)                      0.019122  0.017901
# C(Training)                     0.019916  0.015100
# C(Font)                         0.000041 -0.001157
# C(StudyID):C(Training)          0.012379  0.007572
# C(StudyID):C(Font)              0.000308 -0.000891
# C(Training):C(Font)             0.001588 -0.003207
# C(StudyID):C(Training):C(Font)  0.001351 -0.003444
# Residual                             NaN       NaN
# Overall model F(19, 788) = 2.673, p = 0.0001
#
# # ('StudyID', 'Training', 'Font') (metric: AUC_word)
#                                   sum_sq     df         F    PR(>F)    eta_sq  \
# C(StudyID)                      0.048573    1.0  2.301375  0.130082  0.005705
# C(Training)                     0.108734    4.0  1.287930  0.274142  0.012771
# C(Font)                         0.000087    1.0  0.004123  0.948836  0.000010
# C(StudyID):C(Training)          0.007414    4.0  0.087816  0.986214  0.000871
# C(StudyID):C(Font)              0.007389    1.0  0.350070  0.554422  0.000868
# C(Training):C(Font)             0.083612    4.0  0.990375  0.412617  0.009821
# C(StudyID):C(Training):C(Font)  0.153361    4.0  1.816529  0.124860  0.018013
# Residual                        8.104806  384.0       NaN       NaN       NaN
#
#                                 omega_sq
# C(StudyID)                      0.003218
# C(Training)                     0.002848
# C(Font)                        -0.002463
# C(StudyID):C(Training)         -0.009023
# C(StudyID):C(Font)             -0.001607
# C(Training):C(Font)            -0.000095
# C(StudyID):C(Training):C(Font)  0.008077
# Residual                             NaN
# Overall model F(19, 384) = 1.051, p = 0.4013
#
# # ('StudyID', 'Training', 'Firstfont') (metric: RT)
#                                            sum_sq     df         F    PR(>F)  \
# C(StudyID)                           4.204386e+04    1.0  0.047678  0.827211
# C(Training)                          2.132842e+07    4.0  6.046590  0.000085
# C(Firstfont)                         7.818373e+06    1.0  8.866010  0.002994
# C(StudyID):C(Training)               1.179827e+07    4.0  3.344800  0.009970
# C(StudyID):C(Firstfont)              5.552841e+06    1.0  6.296904  0.012294
# C(Training):C(Firstfont)             9.982260e+06    4.0  2.829963  0.023857
# C(StudyID):C(Training):C(Firstfont)  3.645480e+06    4.0  1.033491  0.388910
# Residual                             6.948874e+08  788.0       NaN       NaN
#
#                                        eta_sq  omega_sq
# C(StudyID)                           0.000056 -0.001111
# C(Training)                          0.028248  0.023548
# C(Firstfont)                         0.010355  0.009176
# C(StudyID):C(Training)               0.015626  0.010941
# C(StudyID):C(Firstfont)              0.007354  0.006179
# C(Training):C(Firstfont)             0.013221  0.008539
# C(StudyID):C(Training):C(Firstfont)  0.004828  0.000156
# Residual                                  NaN       NaN
# Overall model F(19, 788) = 3.545, p = 0.0000
#
# # ('StudyID', 'Training', 'Firstfont') (metric: AUC)
#                                        sum_sq     df          F    PR(>F)  \
# C(StudyID)                           0.146149    1.0  13.377435  0.000272
# C(Training)                          0.191429    4.0   4.380523  0.001651
# C(Firstfont)                         0.010885    1.0   0.996363  0.318499
# C(StudyID):C(Training)               0.063698    4.0   1.457612  0.213290
# C(StudyID):C(Firstfont)              0.008502    1.0   0.778174  0.377969
# C(Training):C(Firstfont)             0.254707    4.0   5.828528  0.000126
# C(StudyID):C(Training):C(Firstfont)  0.183305    4.0   4.194622  0.002287
# Residual                             8.608917  788.0        NaN       NaN
#
#                                        eta_sq  omega_sq
# C(StudyID)                           0.015437  0.014266
# C(Training)                          0.020219  0.015586
# C(Firstfont)                         0.001150 -0.000004
# C(StudyID):C(Training)               0.006728  0.002110
# C(StudyID):C(Firstfont)              0.000898 -0.000256
# C(Training):C(Firstfont)             0.026903  0.022262
# C(StudyID):C(Training):C(Firstfont)  0.019361  0.014729
# Residual                                  NaN       NaN
# Overall model F(19, 788) = 4.822, p = 0.0000
#
# # ('StudyID', 'Training', 'Firstfont') (metric: AUC_word)
#                                        sum_sq     df         F    PR(>F)  \
# C(StudyID)                           0.041489    1.0  2.000891  0.158017
# C(Training)                          0.116520    4.0  1.404854  0.231659
# C(Firstfont)                         0.007340    1.0  0.353979  0.552220
# C(StudyID):C(Training)               0.015310    4.0  0.184593  0.946359
# C(StudyID):C(Firstfont)              0.046909    1.0  2.262306  0.133379
# C(Training):C(Firstfont)             0.214547    4.0  2.586743  0.036627
# C(StudyID):C(Training):C(Firstfont)  0.128267    4.0  1.546489  0.188038
# Residual                             7.962338  384.0       NaN       NaN
#
#                                        eta_sq  omega_sq
# C(StudyID)                           0.004862  0.002426
# C(Training)                          0.013656  0.003926
# C(Firstfont)                         0.000860 -0.001566
# C(StudyID):C(Training)               0.001794 -0.007907
# C(StudyID):C(Firstfont)              0.005498  0.003060
# C(Training):C(Firstfont)             0.025144  0.015386
# C(StudyID):C(Training):C(Firstfont)  0.015032  0.005299
# Residual                                  NaN       NaN
# Overall model F(19, 384) = 1.431, p = 0.1082
#
# # ('StudyID', 'Font', 'Firstfont') (metric: RT)
#                                        sum_sq     df          F    PR(>F)  \
# C(StudyID)                       1.317565e+05    1.0   0.146945  0.701573
# C(Font)                          1.532682e+07    1.0  17.093698  0.000039
# C(Firstfont)                     7.054584e+06    1.0   7.867840  0.005154
# C(StudyID):C(Font)               2.843374e+05    1.0   0.317116  0.573504
# C(StudyID):C(Firstfont)          6.460738e+06    1.0   7.205535  0.007418
# C(Font):C(Firstfont)             4.395009e+06    1.0   4.901668  0.027112
# C(StudyID):C(Font):C(Firstfont)  3.188248e+06    1.0   3.555791  0.059700
# Residual                         7.173083e+08  800.0        NaN       NaN
#
#                                    eta_sq  omega_sq
# C(StudyID)                       0.000175 -0.001013
# C(Font)                          0.020323  0.019112
# C(Firstfont)                     0.009354  0.008156
# C(StudyID):C(Font)               0.000377 -0.000811
# C(StudyID):C(Firstfont)          0.008567  0.007369
# C(Font):C(Firstfont)             0.005828  0.004633
# C(StudyID):C(Font):C(Firstfont)  0.004228  0.003035
# Residual                              NaN       NaN
# Overall model F(7, 800) = 5.891, p = 0.0000
#
# # ('StudyID', 'Font', 'Firstfont') (metric: AUC)
#                                    sum_sq     df          F    PR(>F)  \
# C(StudyID)                       0.243532    1.0  20.979577  0.000005
# C(Font)                          0.000395    1.0   0.034006  0.853740
# C(Firstfont)                     0.016694    1.0   1.438117  0.230799
# C(StudyID):C(Font)               0.004555    1.0   0.392375  0.531232
# C(StudyID):C(Firstfont)          0.006589    1.0   0.567613  0.451431
# C(Font):C(Firstfont)             0.016814    1.0   1.448466  0.229130
# C(StudyID):C(Font):C(Firstfont)  0.037860    1.0   3.261560  0.071297
# Residual                         9.286428  800.0        NaN       NaN
#
#                                    eta_sq  omega_sq
# C(StudyID)                       0.025334  0.024097
# C(Font)                          0.000041 -0.001165
# C(Firstfont)                     0.001737  0.000528
# C(StudyID):C(Font)               0.000474 -0.000733
# C(StudyID):C(Firstfont)          0.000685 -0.000522
# C(Font):C(Firstfont)             0.001749  0.000541
# C(StudyID):C(Font):C(Firstfont)  0.003939  0.002728
# Residual                              NaN       NaN
# Overall model F(7, 800) = 3.980, p = 0.0003
#
# # ('StudyID', 'Font', 'Firstfont') (metric: AUC_word)
#                                    sum_sq     df         F    PR(>F)  \
# C(StudyID)                       0.064985    1.0  3.105421  0.078804
# C(Font)                          0.000087    1.0  0.004158  0.948616
# C(Firstfont)                     0.004084    1.0  0.195177  0.658883
# C(StudyID):C(Font)               0.002837    1.0  0.135580  0.712912
# C(StudyID):C(Firstfont)          0.026164    1.0  1.250309  0.264171
# C(Font):C(Firstfont)             0.055080    1.0  2.632116  0.105518
# C(StudyID):C(Font):C(Firstfont)  0.085788    1.0  4.099538  0.043566
# Residual                         8.286810  396.0       NaN       NaN
#
#                                    eta_sq  omega_sq
# C(StudyID)                       0.007622  0.005155
# C(Font)                          0.000010 -0.002438
# C(Firstfont)                     0.000479 -0.001971
# C(StudyID):C(Font)               0.000333 -0.002116
# C(StudyID):C(Firstfont)          0.003069  0.000613
# C(Font):C(Firstfont)             0.006460  0.003996
# C(StudyID):C(Font):C(Firstfont)  0.010062  0.007589
# Residual                              NaN       NaN
# Overall model F(7, 396) = 1.634, p = 0.1242
#
# # ('Training', 'Font', 'Firstfont') (metric: RT)
#                                         sum_sq     df          F    PR(>F)  \
# C(Training)                       2.277821e+07    4.0   6.464762  0.000040
# C(Font)                           1.532682e+07    1.0  17.399821  0.000034
# C(Firstfont)                      5.967989e+06    1.0   6.775181  0.009417
# C(Training):C(Font)               1.086260e+06    4.0   0.308295  0.872506
# C(Training):C(Firstfont)          8.526485e+06    4.0   2.419931  0.047086
# C(Font):C(Firstfont)              4.640104e+06    1.0   5.267694  0.021987
# C(Training):C(Font):C(Firstfont)  8.643887e+05    4.0   0.245325  0.912523
# Residual                          6.941181e+08  788.0        NaN       NaN
#
#                                     eta_sq  omega_sq
# C(Training)                       0.030238  0.025530
# C(Font)                           0.020346  0.019154
# C(Firstfont)                      0.007922  0.006745
# C(Training):C(Font)               0.001442 -0.003232
# C(Training):C(Firstfont)          0.011319  0.006634
# C(Font):C(Firstfont)              0.006160  0.004984
# C(Training):C(Font):C(Firstfont)  0.001147 -0.003526
# Residual                               NaN       NaN
# Overall model F(19, 788) = 3.595, p = 0.0000
#
# # ('Training', 'Font', 'Firstfont') (metric: AUC)
#                                     sum_sq     df         F    PR(>F)  \
# C(Training)                       0.249878    4.0  5.496347  0.000229
# C(Font)                           0.000395    1.0  0.034732  0.852207
# C(Firstfont)                      0.015453    1.0  1.359623  0.243956
# C(Training):C(Font)               0.018744    4.0  0.412296  0.799861
# C(Training):C(Firstfont)          0.334276    4.0  7.352771  0.000008
# C(Font):C(Firstfont)              0.018778    1.0  1.652171  0.199041
# C(Training):C(Font):C(Firstfont)  0.019941    4.0  0.438621  0.780749
# Residual                          8.956125  788.0       NaN       NaN
#
#                                     eta_sq  omega_sq
# C(Training)                       0.025992  0.021238
# C(Font)                           0.000041 -0.001140
# C(Firstfont)                      0.001607  0.000425
# C(Training):C(Font)               0.001950 -0.002776
# C(Training):C(Firstfont)          0.034771  0.030007
# C(Font):C(Firstfont)              0.001953  0.000770
# C(Training):C(Font):C(Firstfont)  0.002074 -0.002652
# Residual                               NaN       NaN
# Overall model F(19, 788) = 3.027, p = 0.0000
#
# # ('Training', 'Font', 'Firstfont') (metric: AUC_word)
#                                     sum_sq     df         F    PR(>F)  \
# C(Training)                       0.128196    4.0  1.552465  0.186372
# C(Font)                           0.000087    1.0  0.004215  0.948267
# C(Firstfont)                      0.007135    1.0  0.345629  0.556943
# C(Training):C(Font)               0.082216    4.0  0.995648  0.409757
# C(Training):C(Firstfont)          0.202577    4.0  2.453225  0.045517
# C(Font):C(Firstfont)              0.058236    1.0  2.820962  0.093854
# C(Training):C(Font):C(Firstfont)  0.126330    4.0  1.529869  0.192745
# Residual                          7.927265  384.0       NaN       NaN
#
#                                     eta_sq  omega_sq
# C(Training)                       0.015025  0.005334
# C(Font)                           0.000010 -0.002404
# C(Firstfont)                      0.000836 -0.001579
# C(Training):C(Font)               0.009636 -0.000042
# C(Training):C(Firstfont)          0.023743  0.014031
# C(Font):C(Firstfont)              0.006826  0.004395
# C(Training):C(Font):C(Firstfont)  0.014807  0.005116
# Residual                               NaN       NaN
# Overall model F(19, 384) = 1.527, p = 0.0729
